# %%
import pandas as pd
import datetime

# covid data taken from https://covidtracking.com/data/state/michigan/cases
covid_df=pd.read_excel('data\MI_COVID.xlsx')


covid_df['Date']=pd.to_datetime(covid_df.Date) + datetime.timedelta(days=-14)
covid_df.set_index('Date', inplace=True)

#covid_by_month=covid_df[['New cases', 'MONTH']].groupby('MONTH').sum()
#covid_by_month=covid_by_month[:5]

covid_df.head()
# Out:
#             Cases (confirmed plus probable)  New cases  Confirmed cases  \
# Date
# 2020-10-24                           229003       6494           207794
# 2020-10-23                           222509       4246           201569
# 2020-10-22                           218263       6103           197806
# 2020-10-21                           212160       4397           192096
# 2020-10-20                           207763       3437           187995
#
#             Probable Cases
# Date
# 2020-10-24           21209
# 2020-10-23           20940
# 2020-10-22           20457
# 2020-10-21           20064
# 2020-10-20           19768

# %%
#trips info taken from https://data.bts.gov/Research-and-Statistics/Trips-by-Distance/w96p-f2qv
trips_MI=pd.read_csv('data\Trips_MI.csv')
trips_MI['Date']=pd.to_datetime(trips_MI.Date)
trips_MI.set_index('Date', inplace=True)
trips_MI=trips_MI.iloc[:,2:]
trips_MI.tail()
# Out:
#             Population Staying at Home  Population Not Staying at Home  \
# Date
# 2020-10-20                   5106072.0                      14885758.0
# 2020-10-21                   5077576.0                      14914254.0
# 2020-10-22                   4938560.0                      15053270.0
# 2020-10-23                   4637878.0                      15353952.0
# 2020-10-24                   5081616.0                      14910214.0
#
#             Number of Trips  Number of Trips <1  Number of Trips 1-3  \
# Date
# 2020-10-20       56638341.0          12251902.0           13030302.0
# 2020-10-21       56798578.0          12237520.0           13223455.0
# 2020-10-22       57391180.0          12233117.0           13440986.0
# 2020-10-23       63064830.0          13927590.0           14826434.0
# 2020-10-24       62122668.0          14007682.0           15064778.0
#
#             Number of Trips 3-5  Number of Trips 5-10  Number of Trips 10-25  \
# Date
# 2020-10-20            6767188.0             8997863.0              9676930.0
# 2020-10-21            6798972.0             8857183.0              9672250.0
# 2020-10-22            6800473.0             9119085.0              9744509.0
# 2020-10-23            7557186.0             9899424.0             10340775.0
# 2020-10-24            7720921.0             9925141.0              9651742.0
#
#             Number of Trips 25-50  Number of Trips 50-100  \
# Date
# 2020-10-20              3864188.0               1421994.0
# 2020-10-21              3870659.0               1464259.0
# 2020-10-22              3834780.0               1491186.0
# 2020-10-23              4078176.0               1649957.0
# 2020-10-24              3637134.0               1470775.0
#
#             Number of Trips 100-250  Number of Trips 250-500  \
# Date
# 2020-10-20                 514774.0                  81348.0
# 2020-10-21                 552488.0                  88932.0
# 2020-10-22                 598494.0                  96906.0
# 2020-10-23                 654795.0                  97908.0
# 2020-10-24                 541780.0                  76339.0
#
#             Number of Trips >=500
# Date
# 2020-10-20                31852.0
# 2020-10-21                32860.0
# 2020-10-22                31644.0
# 2020-10-23                32585.0
# 2020-10-24                26376.0

# %%
covid_graf=pd.merge(covid_df,trips_MI,how='inner', left_index=True, right_index=True)
covid_graf.head()
# Out:
#             Cases (confirmed plus probable)  New cases  Confirmed cases  \
# Date
# 2020-10-24                           229003       6494           207794
# 2020-10-23                           222509       4246           201569
# 2020-10-22                           218263       6103           197806
# 2020-10-21                           212160       4397           192096
# 2020-10-20                           207763       3437           187995
#
#             Probable Cases  Population Staying at Home  \
# Date
# 2020-10-24           21209                   5081616.0
# 2020-10-23           20940                   4637878.0
# 2020-10-22           20457                   4938560.0
# 2020-10-21           20064                   5077576.0
# 2020-10-20           19768                   5106072.0
#
#             Population Not Staying at Home  Number of Trips  \
# Date
# 2020-10-24                      14910214.0       62122668.0
# 2020-10-23                      15353952.0       63064830.0
# 2020-10-22                      15053270.0       57391180.0
# 2020-10-21                      14914254.0       56798578.0
# 2020-10-20                      14885758.0       56638341.0
#
#             Number of Trips <1  Number of Trips 1-3  Number of Trips 3-5  \
# Date
# 2020-10-24          14007682.0           15064778.0            7720921.0
# 2020-10-23          13927590.0           14826434.0            7557186.0
# 2020-10-22          12233117.0           13440986.0            6800473.0
# 2020-10-21          12237520.0           13223455.0            6798972.0
# 2020-10-20          12251902.0           13030302.0            6767188.0
#
#             Number of Trips 5-10  Number of Trips 10-25  \
# Date
# 2020-10-24             9925141.0              9651742.0
# 2020-10-23             9899424.0             10340775.0
# 2020-10-22             9119085.0              9744509.0
# 2020-10-21             8857183.0              9672250.0
# 2020-10-20             8997863.0              9676930.0
#
#             Number of Trips 25-50  Number of Trips 50-100  \
# Date
# 2020-10-24              3637134.0               1470775.0
# 2020-10-23              4078176.0               1649957.0
# 2020-10-22              3834780.0               1491186.0
# 2020-10-21              3870659.0               1464259.0
# 2020-10-20              3864188.0               1421994.0
#
#             Number of Trips 100-250  Number of Trips 250-500  \
# Date
# 2020-10-24                 541780.0                  76339.0
# 2020-10-23                 654795.0                  97908.0
# 2020-10-22                 598494.0                  96906.0
# 2020-10-21                 552488.0                  88932.0
# 2020-10-20                 514774.0                  81348.0
#
#             Number of Trips >=500
# Date
# 2020-10-24                26376.0
# 2020-10-23                32585.0
# 2020-10-22                31644.0
# 2020-10-21                32860.0
# 2020-10-20                31852.0

# %%
import seaborn as sns

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(covid_graf[['New cases','Number of Trips <1', 'Number of Trips 1-3','Number of Trips 3-5', 'Number of Trips 5-10', 
                        'Number of Trips 10-25','Number of Trips 25-50','Number of Trips 50-100','Number of Trips 100-250',
                        'Number of Trips 250-500', 'Number of Trips >=500']].corr(),vmax=0.5, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.pairplot(covid_graf[['New cases','Number of Trips 25-50','Number of Trips 50-100']], plot_kws=dict(marker="+", linewidth=2));#

# %%
sns.jointplot(covid_graf['Number of Trips 25-50'], covid_graf['New cases'], kind='kde', space=0.5)
